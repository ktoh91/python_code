# %%
import warnings
warnings.filterwarnings(action='ignore') 
import pandas as pd
import numpy as np
from numpy import std, mean, sqrt
import matplotlib.pyplot as plt
import matplotlib
from numpy import std, mean, sqrt
from scipy import stats
from matplotlib.backends.backend_pdf import PdfPages

# %%
tmp2['raw_fire_date'].hist(cumulative=True, density=1, histtype='step', bins=10000, lw=3, color='g')
plt.ylabel("CDF", fontsize=15)
plt.xlabel("total usage date", fontsize=13)
# Out:
# Text(0.5, 0, 'total usage date')

# %%
tmp3['raw_fire_date'].hist(cumulative=True, density=1, histtype='step', bins=10000, lw=3, color='r')
plt.ylabel("CDF", fontsize=15)
plt.xlabel("total usage date", fontsize=13)
# Out:
# Text(0.5, 0, 'total usage date')
